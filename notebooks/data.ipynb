# %% [markdown]
# # Albin

# %% [markdown]
# # Plot data from all ToF experiments

# %%
import sys
import os
import glob

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from utils.data import load_tof
from utils.plot import plot_bananas

# %%
file_paths = glob.glob("../data/tof_erda/raw/*.lst")
# All file paths 
file_paths
# Out:
# ['../data/tof_erda/raw\\I_36MeV_SH2-12_S18.lst',
#  '../data/tof_erda/raw\\I_36MeV_SH2-14_Y-Deltt.lst',
#  '../data/tof_erda/raw\\I_36MeV_SH2-15_25B.lst',
#  '../data/tof_erda/raw\\I_36MeV_SH2-1_TiN-ref.lst',
#  '../data/tof_erda/raw\\I_36MeV_SH2-2_Au-ref.lst',
#  '../data/tof_erda/raw\\I_36MeV_SH2-3_SiC-ref.lst',
#  '../data/tof_erda/raw\\I_36MeV_SH2-4_Cu-ref.lst',
#  '../data/tof_erda/raw\\I_36MeV_SH2-5_AKHEN432-big.lst',
#  '../data/tof_erda/raw\\I_36MeV_SH2-7_AKHEN432-small.lst',
#  '../data/tof_erda/raw\\I_36MeV_SH2-8_screen.lst',
#  '../data/tof_erda/raw\\I_36MeV_SH2-9_job32.lst']

# %%
for file in file_paths:
    X, y, phi = load_tof(file)
    plot_bananas(X, y, title=file)
